# %%
a = []
opciones = ["añadir", "eliminar", "actualizar"]

for i, a in enumerate(opciones): 
    print("Opción", i, ":", a)

eleccion = int(input("Escoja una opcion: "))
# Out:
# Opción 0 : añadir
# Opción 1 : eliminar
# Opción 2 : actualizar

# %%
if eleccion == 0 {
    nuevo = input("Añadir: ")
    a.append(nuevo)
    print("Elemento", nuevo, "añadido")
}elif eleccion == 1 {
    borra = input("Eliminar: ")
    if borra in a{
        a.remove(borra)
        print("Elemento", borra, "borrado")
    }else{
        print("Elemento no encontrado")
    }
}elif eleccion = 2{
    cambia = input("Elije el elemento que quiera cambiar: ")
    nuevo = input("Nuevo valor:")
    if cambia in a{
        a[a.index(cambia)] = nuevo
    }else{
        print("Elemento no encontrado")
    }
}else{
    print("Opción no disponible")
}

# %%
print("Antes del input")
x = input("Escribe algo: ")
print("Después del input:", x)
# Out:
# Antes del input
