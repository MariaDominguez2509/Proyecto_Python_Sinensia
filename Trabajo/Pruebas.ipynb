# %%
from Persona import Persona, Cliente, Empleado
from Empresa import Empresa

# %% [markdown]
# Creamos Personas (Clientes y Empleados)

# %%
cliente1 = Cliente("María", 1)
#cliente2 = Cliente("A",1) esto hace saltar un error
empresa1 = Empresa("nombreEmpresa", 1)
empleado1 = Empleado("Pepe", 2)
empleado2 = Empleado("Manolo", 3)
# Out:
# Persona creada
# Empresa creada
# Persona creada
# Persona creada

# %%
print(Empresa.registro)
print(Persona.registro)
# Out:
# [('nombreEmpresa', 1)]
# [('María', 'Cliente'), ('Pepe', 'Empleado'), ('Manolo', 'Empleado')]

# %%
empresa1.contrata(empleado1)
empresa1.contrata(empleado2)
empresa1.trabajadores
# Out:
# nombreEmpresa ha contratado a Pepe
# nombreEmpresa ha contratado a Manolo
# [('Pepe', 2), ('Manolo', 3)]

# %%
print(Persona.registro)
# Out:
# [('María', 'Cliente'), ('Pepe', 'Empleado'), ('Manolo', 'Empleado')]
